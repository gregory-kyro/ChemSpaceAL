# %%
from rdkit import Chem
from rdkit.Chem import Draw

m = Chem.MolFromSmiles('c1ccccc1c2ccccc2')
img = Draw.MolToImage(m)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
r_smile = '!C(CCCC(O)=O)c1c(F)cc(cc1F)-c1cccnc1OC1CCCC1~1ccc(cc1)C(F)(F)F~1nnn[nH]1~~(cs1)C(=O)NCC(=O)NO~cc[n+]([O-])cc1~~ccc[n+]1[O-]~1ccccc1~~1~c1ccccc1~~~'
smile = r_smile[1:r_smile.index('~')]
print(smile)
m = Chem.MolFromSmiles(smile)
print(Chem.MolToSmiles(m))
img = Draw.MolToImage(m)
img
# Out:
# C(CCCC(O)=O)c1c(F)cc(cc1F)-c1cccnc1OC1CCCC1
# O=C(O)CCCCc1c(F)cc(-c2cccnc2OC2CCCC2)cc1F
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
